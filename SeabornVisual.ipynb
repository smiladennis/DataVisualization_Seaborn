# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# conda list

# %%
import seaborn as sns

# %% [raw]
# # distplot is histogram and density curve,
# # distplot is univariate

# %%
sns.distplot(dataset['ssc_p'],hist=True,kde=True,kde_kws={'color':'Red'})
# it is deprecated in v0.14 of seaborn instead histplot and displot are added
# Out:
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
# histplot & displot is bivariate 
# in displot ,kind of kde:hist are bivariate,and ecdf is univariate only

# %%
sns.histplot(x=dataset['ssc_p'],kde=True)
# Out:
# <Axes: xlabel='ssc_p', ylabel='Count'>

# %%
sns.displot(x=dataset['ssc_p'],kind='hist')

# %%
sns.displot(dataset['ssc_p'],kind='kde')

# %%
sns.displot(dataset['ssc_p'],kind='ecdf')

# %% [markdown]
# # For Bivariate Analysis : Distribution Plot

# %%
# jointplot is scatterplot and histogram

# %%
sns.jointplot(x='ssc_p',y='salary',data=dataset,kind='scatter')
plt.show()

#kind=“scatter” | “kde” | “hist” | “hex” | “reg” | “resid”

# %%
sns.jointplot(x='ssc_p',y='salary',data=dataset,kind='hex')
plt.show()  # shows hexagonal arrangement ,if is more density means darkened

# %%
sns.jointplot(x='ssc_p',y='salary',data=dataset,kind='kde')
plt.show() # kde is kernel density estimate

# %%
sns.jointplot(x='ssc_p',y='salary',data=dataset,kind='hist') # this heatmap style
plt.show()

# %%
# To evaluate correlation,pairplot is plotted
sns.pairplot(dataset,hue='gender',diag_kind='kde',kind='scatter',palette='husl')
plt.show()

# %% [markdown]
# # For CATEGORICAL PLOT

# %%
# Categorical strip plot is plotted between categorical value and numerical value

# %%
sns.stripplot(x='ssc_b',y='ssc_p',data=dataset)
plt.show()

# %%
sns.stripplot(x='gender',y='ssc_p',data=dataset,jitter=True)
plt.show()

# %%
sns.swarmplot(x='gender',y='ssc_p',data=dataset) # the data points do not overlap,adjusts points along categorical axis
plt.show()

# %% [markdown]
# # Distribution Plot

# %%
sns.violinplot(x='gender',y='ssc_p',data=dataset)
plt.show()

# %%
sns.violinplot(x='specialisation',y='salary',data=dataset,hue='gender')
plt.show()

# %%
sns.boxplot(x = "ssc_b", y = "ssc_p", data = dataset )
plt.show()

# %%
sns.boxplot(x = "ssc_b", y = "ssc_p", data = dataset,hue="gender" )
plt.show()

# %%
sns.barplot(x = "ssc_b", y = "ssc_p", data = dataset,hue='gender')
plt.show()

# %%
sns.barplot(x = "ssc_b", y = "ssc_p", data = dataset,hue='gender')
plt.show()

# %%
sns.countplot(x = "ssc_b",data = dataset,hue='gender')
plt.show()

# %%
sns.pointplot(y = "ssc_p",x="hsc_b",data =dataset,hue='gender')
plt.show()

# %%
sns.boxplot(data = dataset, orient = "h")
plt.show()

# %%
df = sns.load_dataset('exercise')
sns.catplot(x = "time", y = "pulse", hue = "kind", kind = 'violin', col = "diet", data = df);
plt.show()

# %%
df.shape
# Out:
# (90, 6)

# %%
import pandas as pd
from matplotlib import pyplot as plt
df = sns.load_dataset('tips')
sns.regplot(x = "total_bill", y = "tip", data = df)
sns.lmplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %%
df = sns.load_dataset('anscombe')
sns.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
plt.show()

# %%
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"),order=2)
plt.show()

# %%
df = sns.load_dataset('tips')
g = sns.FacetGrid(df, col = "time")
g.map(plt.hist, "tip")
plt.show()

# %%
df = sns.load_dataset('iris')
g = sns.PairGrid(df)
g.map(plt.scatter);
plt.show()
